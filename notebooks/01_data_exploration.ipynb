# %% [markdown]
# # WLASL Data Exploration
#
# Quick checks for metadata integrity, class counts, and local video availability.

# %%
from pathlib import Path

import pandas as pd

from src.data.wlasl_loader import load_wlasl_metadata

metadata = load_wlasl_metadata(
    Path('../data/raw/wlasl/WLASL_v0.3.json'),
    video_dir=Path('../data/raw/wlasl/videos'),
)
metadata.head()

# %%
metadata['gloss'].value_counts().head(20)
